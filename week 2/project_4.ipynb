# %%
name = input("Name: ")
ex = int(input("Years of Experience: "))
age =int(input("Age: "))

print(name)
print(ex)
print(age)

if ex > 25 and age >= 55:
    print("Annual Tax Revenue: ₦ 5,600,000")
elif ex > 20 and ex < 25 and age >= 45 and age < 55:
    print("Annual Tax Revenue: ₦ 4,480,000")
elif ex > 10 and ex < 20 and age >= 35 and age < 45:
    print("Annual Tax Revenue: ₦ 1,500,000")
elif ex < 10 and age < 35:
    print("Annual Tax Revenue: ₦ 550,000")
else: 
    print("Not Included!!!")
