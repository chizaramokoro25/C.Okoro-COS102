# %% [markdown]
# START
# INPUT cashier name
# PRINT cashier nme
# INPUT customer phone
# PRINT customer phone
# INPUT item code
# PRINT item code
# INPUT quantity
# PRINT quantity
# INPUT price
# LET total = quantity * price
# IF total > 20000
#   LET discount = total * 0.05
# ELSE
#    PRINT total
# END

# %% [markdown]
# ![image.png](attachment:34cd9f0a-78b0-4d0d-8ef0-a1e702e12a0d.png)

# %% [markdown]
# ![image.png](attachment:48b62c98-4a58-4aae-86d0-b7df8e165aad.png)

# %% [markdown]
# START
# INPUT first name
# DISPLAY first name
# INPUT second name
# DISPLAY second name
# INPUT first age
# DISPLAY first age
# INPUT second age
# DISPLAY second age
# LET temp = first age
# LET first age = second age
# LET second age = first age
# PRINT first age
# PRINT second age
# END

# %% [markdown]
# ![image.png](attachment:5f78ea7c-75e8-4eac-b9a1-c49a231bea84.png)
